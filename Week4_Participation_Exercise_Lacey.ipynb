# %% [markdown]
# <a href="https://colab.research.google.com/github/laceywang11/MSSP6070/blob/main/Week4_Participation_Exercise_Lacey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a. Find the 95th percentile of earthquake magnitude in Japan using magType of 'mb'

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MSSP 6070/Colab Notebooks/Week4 Participation Exercise/Working with Pandas DataFrames/parsed.csv')
SubsetA = df[(df['magType'] == 'mb') & (df['place'].str.contains('Japan', case=False, na=False))]
p95 = SubsetA['mag'].quantile(0.95)
print(p95)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 4.9

# %% [markdown]
# b. Find the percentage of earthquakes in Indonesia that were coupled with tsunamis.

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MSSP 6070/Colab Notebooks/Week4 Participation Exercise/Working with Pandas DataFrames/parsed.csv')
Indonesia = df[df['place'].str.contains('Indonesia', case=False, na=False)]
Earth_tsunamis = (Indonesia['tsunami'] == 1).mean()*100
print(Earth_tsunamis)
print(round(Earth_tsunamis, 2))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 23.12925170068027
# 23.13

# %% [markdown]
# c. Get summary statistics for earthquakes in Nevada

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MSSP 6070/Colab Notebooks/Week4 Participation Exercise/Working with Pandas DataFrames/parsed.csv')
Nevada = df[df['place'].str.contains('Nevada', case=False, na=False)]
Summary = (Nevada.describe())
print(Summary)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  677.000000  15.000000  677.000000  677.000000  1.00
# mean    2.440000    0.166982   2.400000  154.029527    0.491728  2.84
# std     0.501142    0.166400   4.626013   68.769713    0.689560   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.054000   1.000000   97.670000   -0.100000  2.84
# 50%     2.200000    0.113000   1.000000  149.550000    0.400000  2.84
# 75%     2.900000    0.234000   1.000000  200.470000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  677.000000  677.000000  677.000000  6.770000e+02    677.0  677.0
# ...

# %% [markdown]
# d. Add a column to the dataframe indicating whether or not the earthquake happened in a country or US state that is on the Ring of Fire. Use Bolivia, Chile, Ecuador, Peru, Costa Rica, Guatemala, Mexico (be sure not to select New Mexico), Japan, Philippines, Indonesia, New Zealand, Antarctica (look for the Antarctic), Canada, Fiji, Alaska, Washington, California, Russia, Taiwan, Tonga, and the Kermadec Islands).

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/MSSP 6070/Colab Notebooks/Week4 Participation Exercise/Working with Pandas DataFrames/parsed.csv')
Ring_of_fire = ['Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica', 'Guatemala', 'Mexico', 'Japan', 'Philippines', 'Indonesia', 'New Zealand', 'Antarctic', 'Canada',
    'Fiji', 'Alaska', 'Washington', 'California', 'Russia', 'Taiwan', 'Tonga', 'Kermadec']
pattern = '|'.join(Ring_of_fire)
df['Ring_of_Fire'] = df['parsed_place'].str.contains(pattern, case=False, na=False)
print(df[['parsed_place','Ring_of_Fire']])
# Out:
# Mounted at /content/drive
#      parsed_place  Ring_of_Fire
# 0      California          True
# 1      California          True
# 2      California          True
# 3      California          True
# 4      California          True
# ...           ...           ...
# 9327   California          True
# 9328   California          True
# 9329  Puerto Rico         False
# 9330   California          True
# 9331   California          True
#
# [9332 rows x 2 columns]

# %% [markdown]
# e. Calculate the number of earthquakes in the Ring of Fire locations and the number outside of them,

# %%
earthquake_df = df[df['type'] == 'earthquake']
Ring_of_fire = ['Bolivia', 'Chile', 'Ecuador', 'Peru', 'Costa Rica', 'Guatemala', 'Mexico', 'Japan', 'Philippines', 'Indonesia', 'New Zealand', 'Antarctic', 'Canada',
    'Fiji', 'Alaska', 'Washington', 'California', 'Russia', 'Taiwan', 'Tonga', 'Kermadec']
pattern = '|'.join(Ring_of_fire)
earthquake_df = df[df['type'] == 'earthquake']
in_ring = earthquake_df['Ring_of_Fire'].sum()
outside_ring = len(earthquake_df) - in_ring
print(Ring_of_fire_count)
print(outside_count)
# Out:
# 7005
# 2076

# %% [markdown]
# f. Find the tsunami count along the Ring of Fire.

# %%
tsunami_count = len(df[(df['Ring_of_Fire']) & (df['tsunami'] == 1)])
print(tsunami_count)
# Out:
# 45
